# %% [markdown]
# <a href="https://colab.research.google.com/github/pxu/Generative_Deep_Learning_2nd_Edition/blob/main/notebooks/11_music/01_transformer/transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎶 Music Generation with Transformers

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own Transformer model to generate music in the style of the Bach cello suites

# %%
# %load_ext autoreload
# %autoreload 2

import os
import glob
import numpy as np
import time
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models, losses, callbacks

import music21

from transformer_utils import (
    parse_midi_files,
    load_parsed_files,
    get_midi_note,
    SinePositionEncoding,
)

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
PARSE_MIDI_FILES = True
PARSED_DATA_PATH = "/app/notebooks/11_music/01_transformer/parsed_data/"
DATASET_REPETITIONS = 1

SEQ_LEN = 50
EMBEDDING_DIM = 256
KEY_DIM = 256
N_HEADS = 5
DROPOUT_RATE = 0.3
FEED_FORWARD_DIM = 256
LOAD_MODEL = False

# optimization
EPOCHS = 5000
BATCH_SIZE = 256

GENERATE_LEN = 50

# %% [markdown]
# ## 1. Prepare the Data

# %%
# Load the data
file_list = glob.glob("/app/data/bach-cello/*.mid")
print(f"Found {len(file_list)} midi files")

# %%
parser = music21.converter

# %%
example_score = (
    music21.converter.parse(file_list[1]).splitAtQuarterLength(12)[0].chordify()
)

# %%
example_score.show()

# %%
example_score.show("text")

# %%
if PARSE_MIDI_FILES:
    notes, durations = parse_midi_files(
        file_list, parser, SEQ_LEN + 1, PARSED_DATA_PATH
    )
else:
    notes, durations = load_parsed_files()

# %%
example_notes = notes[658]
example_durations = durations[658]
print("\nNotes string\n", example_notes, "...")
print("\nDuration string\n", example_durations, "...")

# %% [markdown]
# ## 2. Tokenize the data <a name="tokenize"></a>

# %%
def create_dataset(elements):
    ds = (
        tf.data.Dataset.from_tensor_slices(elements)
        .batch(BATCH_SIZE, drop_remainder=True)
        .shuffle(1000)
    )
    vectorize_layer = layers.TextVectorization(
        standardize=None, output_mode="int"
    )
    vectorize_layer.adapt(ds)
    vocab = vectorize_layer.get_vocabulary()
    return ds, vectorize_layer, vocab


notes_seq_ds, notes_vectorize_layer, notes_vocab = create_dataset(notes)
durations_seq_ds, durations_vectorize_layer, durations_vocab = create_dataset(
    durations
)
seq_ds = tf.data.Dataset.zip((notes_seq_ds, durations_seq_ds))

# %%
# Display the same example notes and durations converted to ints
example_tokenised_notes = notes_vectorize_layer(example_notes)
example_tokenised_durations = durations_vectorize_layer(example_durations)
print("{:10} {:10}".format("note token", "duration token"))
for i, (note_int, duration_int) in enumerate(
    zip(
        example_tokenised_notes.numpy()[:11],
        example_tokenised_durations.numpy()[:11],
    )
):
    print(f"{note_int:10}{duration_int:10}")

# %%
notes_vocab_size = len(notes_vocab)
durations_vocab_size = len(durations_vocab)

# Display some token:note mappings
print(f"\nNOTES_VOCAB: length = {len(notes_vocab)}")
for i, note in enumerate(notes_vocab[:10]):
    print(f"{i}: {note}")

print(f"\nDURATIONS_VOCAB: length = {len(durations_vocab)}")
# Display some token:duration mappings
for i, note in enumerate(durations_vocab[:10]):
    print(f"{i}: {note}")

# %% [markdown]
# ## 3. Create the Training Set <a name="create"></a>

# %%
# Create the training set of sequences and the same sequences shifted by one note
def prepare_inputs(notes, durations):
    notes = tf.expand_dims(notes, -1)
    durations = tf.expand_dims(durations, -1)
    tokenized_notes = notes_vectorize_layer(notes)
    tokenized_durations = durations_vectorize_layer(durations)
    x = (tokenized_notes[:, :-1], tokenized_durations[:, :-1])
    y = (tokenized_notes[:, 1:], tokenized_durations[:, 1:])
    return x, y


ds = seq_ds.map(prepare_inputs).repeat(DATASET_REPETITIONS)

# %%
example_input_output = ds.take(1).get_single_element()
print(example_input_output)

# %% [markdown]
# ## 5. Create the causal attention mask function <a name="causal"></a>

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)


np.transpose(causal_attention_mask(1, 10, 10, dtype=tf.int32)[0])

# %% [markdown]
# ## 6. Create a Transformer Block layer <a name="transformer"></a>

# %%
class TransformerBlock(layers.Layer):
    def __init__(
        self,
        num_heads,
        key_dim,
        embed_dim,
        ff_dim,
        name,
        dropout_rate=DROPOUT_RATE,
    ):
        super(TransformerBlock, self).__init__(name=name)
        self.num_heads = num_heads
        self.key_dim = key_dim
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.dropout_rate = dropout_rate
        self.attn = layers.MultiHeadAttention(
            num_heads, key_dim, output_shape=embed_dim
        )
        self.dropout_1 = layers.Dropout(self.dropout_rate)
        self.ln_1 = layers.LayerNormalization(epsilon=1e-6)
        self.ffn_1 = layers.Dense(self.ff_dim, activation="relu")
        self.ffn_2 = layers.Dense(self.embed_dim)
        self.dropout_2 = layers.Dropout(self.dropout_rate)
        self.ln_2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(
            batch_size, seq_len, seq_len, tf.bool
        )
        attention_output, attention_scores = self.attn(
            inputs,
            inputs,
            attention_mask=causal_mask,
            return_attention_scores=True,
        )
        attention_output = self.dropout_1(attention_output)
        out1 = self.ln_1(inputs + attention_output)
        ffn_1 = self.ffn_1(out1)
        ffn_2 = self.ffn_2(ffn_1)
        ffn_output = self.dropout_2(ffn_2)
        return (self.ln_2(out1 + ffn_output), attention_scores)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "key_dim": self.key_dim,
                "embed_dim": self.embed_dim,
                "num_heads": self.num_heads,
                "ff_dim": self.ff_dim,
                "dropout_rate": self.dropout_rate,
            }
        )
        return config

# %% [markdown]
# ## 7. Create the Token and Position Embedding <a name="embedder"></a>

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.token_emb = layers.Embedding(
            input_dim=vocab_size,
            output_dim=embed_dim,
            embeddings_initializer="he_uniform",
        )
        self.pos_emb = SinePositionEncoding()

    def call(self, x):
        embedding = self.token_emb(x)
        positions = self.pos_emb(embedding)
        return embedding + positions

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "vocab_size": self.vocab_size,
                "embed_dim": self.embed_dim,
            }
        )
        return config

# %%
tpe = TokenAndPositionEmbedding(notes_vocab_size, 32)
token_embedding = tpe.token_emb(example_tokenised_notes)
position_embedding = tpe.pos_emb(token_embedding)
embedding = tpe(example_tokenised_notes)
plt.imshow(
    np.transpose(token_embedding),
    cmap="coolwarm",
    interpolation="nearest",
    origin="lower",
)
plt.show()
plt.imshow(
    np.transpose(position_embedding),
    cmap="coolwarm",
    interpolation="nearest",
    origin="lower",
)
plt.show()
plt.imshow(
    np.transpose(embedding),
    cmap="coolwarm",
    interpolation="nearest",
    origin="lower",
)
plt.show()

# %% [markdown]
# ## 8. Build the Transformer model <a name="transformer_decoder"></a>

# %%
note_inputs = layers.Input(shape=(None,), dtype=tf.int32)
durations_inputs = layers.Input(shape=(None,), dtype=tf.int32)
note_embeddings = TokenAndPositionEmbedding(
    notes_vocab_size, EMBEDDING_DIM // 2
)(note_inputs)
duration_embeddings = TokenAndPositionEmbedding(
    durations_vocab_size, EMBEDDING_DIM // 2
)(durations_inputs)
embeddings = layers.Concatenate()([note_embeddings, duration_embeddings])
x, attention_scores = TransformerBlock(
    N_HEADS, KEY_DIM, EMBEDDING_DIM, FEED_FORWARD_DIM, name="attention"
)(embeddings)
note_outputs = layers.Dense(
    notes_vocab_size, activation="softmax", name="note_outputs"
)(x)
duration_outputs = layers.Dense(
    durations_vocab_size, activation="softmax", name="duration_outputs"
)(x)
model = models.Model(
    inputs=[note_inputs, durations_inputs],
    outputs=[note_outputs, duration_outputs],  # attention_scores
)
model.compile(
    "adam",
    loss=[
        losses.SparseCategoricalCrossentropy(),
        losses.SparseCategoricalCrossentropy(),
    ],
)
att_model = models.Model(
    inputs=[note_inputs, durations_inputs], outputs=attention_scores
)

# %%
model.summary()

# %%
if LOAD_MODEL:
    model.load_weights("./checkpoint/checkpoint.ckpt")
    # model = models.load_model('./models/model', compile=True)

# %% [markdown]
# ## 9. Train the Transformer <a name="train"></a>

# %%
import os
import glob
import numpy as np
import time
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models, losses, callbacks

import music21

from transformer_utils import (
    parse_midi_files,
    load_parsed_files,
    get_midi_note,
    SinePositionEncoding,
)
# Create a MusicGenerator checkpoint
class MusicGenerator(callbacks.Callback):
    def __init__(self, index_to_note, index_to_duration, top_k=10):
        self.index_to_note = index_to_note
        self.note_to_index = {
            note: index for index, note in enumerate(index_to_note)
        }
        self.index_to_duration = index_to_duration
        self.duration_to_index = {
            duration: index for index, duration in enumerate(index_to_duration)
        }

    def sample_from(self, probs, temperature):
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def get_note(self, notes, durations, temperature):
        sample_note_idx = 1
        while sample_note_idx == 1:
            sample_note_idx, note_probs = self.sample_from(
                notes[0][-1], temperature
            )
            sample_note = self.index_to_note[sample_note_idx]

        sample_duration_idx = 1
        while sample_duration_idx == 1:
            sample_duration_idx, duration_probs = self.sample_from(
                durations[0][-1], temperature
            )
            sample_duration = self.index_to_duration[sample_duration_idx]

        new_note = get_midi_note(sample_note, sample_duration)

        return (
            new_note,
            sample_note_idx,
            sample_note,
            note_probs,
            sample_duration_idx,
            sample_duration,
            duration_probs,
        )

    def generate(self, start_notes, start_durations, max_tokens, temperature): # Added temperature parameter
        attention_model = models.Model(
            inputs=self.model.input,
            outputs=self.model.get_layer("attention").output,
        )

        start_note_tokens = [self.note_to_index.get(x, 1) for x in start_notes]
        start_duration_tokens = [
            self.duration_to_index.get(x, 1) for x in start_durations
        ]
        sample_note = None
        sample_duration = None
        info = []
        midi_stream = music21.stream.Stream()

        midi_stream.append(music21.clef.BassClef())

        for sample_note, sample_duration in zip(start_notes, start_durations):
            new_note = get_midi_note(sample_note, sample_duration)
            if new_note is not None:
                midi_stream.append(new_note)

        while len(start_note_tokens) < max_tokens:
            x1 = np.array([start_note_tokens])
            x2 = np.array([start_duration_tokens])
            notes, durations = self.model.predict([x1, x2], verbose=0)

            repeat = True

            while repeat:
                (
                    new_note,
                    sample_note_idx,
                    sample_note,
                    note_probs,
                    sample_duration_idx,
                    sample_duration,
                    duration_probs,
                ) = self.get_note(notes, durations, temperature)

                if (
                    isinstance(new_note, music21.chord.Chord)
                    or isinstance(new_note, music21.note.Note)
                    or isinstance(new_note, music21.note.Rest)
                ) and sample_duration == "0.0":
                    repeat = True
                else:
                    repeat = False

            if new_note is not None:
                midi_stream.append(new_note)

            _, att = attention_model.predict([x1, x2], verbose=0)

            info.append(
                {
                    "prompt": [start_notes.copy(), start_durations.copy()],
                    "midi": midi_stream,
                    "chosen_note": (sample_note, sample_duration),
                    "note_probs": note_probs,
                    "duration_probs": duration_probs,
                    "atts": att[0, :, -1, :],
                }
            )
            start_note_tokens.append(sample_note_idx)
            start_duration_tokens.append(sample_duration_idx)
            start_notes.append(sample_note)
            start_durations.append(sample_duration)

            if sample_note == "START":
                break

        return info

    def on_epoch_end(self, epoch, logs=None):
        info = self.generate(
            ["START"], ["0.0"], max_tokens=GENERATE_LEN, temperature=0.5
        )
        midi_stream = info[-1]["midi"].chordify()
        print(info[-1]["prompt"])
        midi_stream.show()
        midi_stream.write(
            "midi",
            fp=os.path.join(
                "/app/notebooks/11_music/01_transformer/output",
                "output-" + str(epoch).zfill(4) + ".mid",
            ),
        )

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
music_generator = MusicGenerator(notes_vocab, durations_vocab)

# %%
model.fit(
    ds,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        music_generator,
    ],
)
# Out:
# Epoch 1/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - duration_outputs_loss: 1.6514 - loss: 5.2491 - note_outputs_loss: 3.5977
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis 3 of a tensor of shape (1, 5, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Durations: ['0.0', np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5439 - loss: 1.4713 - note_outputs_loss: 0.9274
# Epoch 168/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5765 - loss: 1.4721 - note_outputs_loss: 0.8956
# Epoch 167
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('C3'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('G#3'), np.str_('G#3'), np.str_('F3'), np.str_('B-3'), np.str_('E3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('G#2'), np.str_('G2')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5405 - loss: 1.4624 - note_outputs_loss: 0.9220
# Epoch 169/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5285 - loss: 1.4468 - note_outputs_loss: 0.9183
# Epoch 168
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('F2'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C#4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C4'), np.str_('G#3'), np.str_('E-3')]
# Durations: ['0.0', np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5402 - loss: 1.4643 - note_outputs_loss: 0.9241
# Epoch 170/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5811 - loss: 1.4397 - note_outputs_loss: 0.8586
# Epoch 169
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('F2'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('F3'), np.str_('E3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('G3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5390 - loss: 1.4582 - note_outputs_loss: 0.9192
# Epoch 171/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5005 - loss: 1.3772 - note_outputs_loss: 0.8767
# Epoch 170
# Notes:     ['START', np.str_('E-:major'), np.str_('3/4TS'), np.str_('B-3'), np.str_('E-4'), np.str_('C#4'), np.str_('C#4'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('F3'), np.str_('C#3'), np.str_('E3'), np.str_('C#3'), np.str_('E3'), np.str_('F#3'), np.str_('E3'), np.str_('F#3'), np.str_('G#3'), np.str_('E3'), np.str_('C#4'), np.str_('C#4'), np.str_('A3'), np.str_('C#4'), np.str_('D4'), np.str_('E4'), np.str_('A3'), np.str_('C#4'), np.str_('E4'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('C#4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('3.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5372 - loss: 1.4536 - note_outputs_loss: 0.9165
# Epoch 172/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5326 - loss: 1.4155 - note_outputs_loss: 0.8829
# Epoch 171
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('C3'), np.str_('C3'), np.str_('B-2'), np.str_('A2'), np.str_('E3'), np.str_('G3'), np.str_('C4'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('B-2'), np.str_('F3'), np.str_('G3'), np.str_('A3'), np.str_('A3'), np.str_('A3'), np.str_('G3'), np.str_('F3'), np.str_('E3'), np.str_('F3'), np.str_('A3'), np.str_('C4'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('C4'), np.str_('A3'), np.str_('B-3'), np.str_('C4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('2.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5381 - loss: 1.4508 - note_outputs_loss: 0.9127
# Epoch 173/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5529 - loss: 1.4048 - note_outputs_loss: 0.8519
# Epoch 172
# Notes:     ['START', np.str_('E-:major'), np.str_('3/4TS'), np.str_('B-3'), np.str_('C4'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('F3'), np.str_('A3'), np.str_('A3'), np.str_('B3'), np.str_('C4'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('F2'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('B-2'), np.str_('G#3'), np.str_('F3'), np.str_('E-2'), np.str_('G#3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5401 - loss: 1.4565 - note_outputs_loss: 0.9164
# Epoch 174/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5575 - loss: 1.4145 - note_outputs_loss: 0.8570
# Epoch 173
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('G#3'), np.str_('G#3'), np.str_('G#3'), np.str_('F3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('F3'), np.str_('F3'), np.str_('G3'), np.str_('A3'), np.str_('B-3'), np.str_('G3'), np.str_('F3'), np.str_('C3'), np.str_('E-3'), np.str_('B-2'), np.str_('rest')]
# Durations: ['0.0', np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5367 - loss: 1.4507 - note_outputs_loss: 0.9140
# Epoch 175/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5880 - loss: 1.4876 - note_outputs_loss: 0.8996
# Epoch 174
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C#4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C#4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3')]
# Durations: ['0.0', np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5418 - loss: 1.4564 - note_outputs_loss: 0.9146
# Epoch 176/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5806 - loss: 1.4690 - note_outputs_loss: 0.8884
# Epoch 175
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('C3'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F#3'), np.str_('A3'), np.str_('C4'), np.str_('E-4'), np.str_('D4'), np.str_('C4'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('F#3'), np.str_('A3'), np.str_('D3'), np.str_('A3'), np.str_('F#3'), np.str_('B3'), np.str_('C4'), np.str_('A3'), np.str_('C4'), np.str_('C4'), np.str_('D4'), np.str_('B3'), np.str_('A3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('3.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - duration_outputs_loss: 0.5413 - loss: 1.4512 - note_outputs_loss: 0.9100
# Epoch 177/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5441 - loss: 1.4128 - note_outputs_loss: 0.8688
# Epoch 176
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('B2'), np.str_('C3'), np.str_('G#3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('A2'), np.str_('B2'), np.str_('D3'), np.str_('G3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('G3'), np.str_('E-3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5369 - loss: 1.4399 - note_outputs_loss: 0.9030
# Epoch 178/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5427 - loss: 1.4398 - note_outputs_loss: 0.8971
# Epoch 177
# Notes:     ['START', np.str_('E-:major'), np.str_('12/8TS'), np.str_('rest'), np.str_('E-3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-2'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('F3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5388 - loss: 1.4452 - note_outputs_loss: 0.9065
# Epoch 179/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5482 - loss: 1.4332 - note_outputs_loss: 0.8851
# Epoch 178
# Notes:     ['START', np.str_('E-:major'), np.str_('3/8TS'), np.str_('rest'), np.str_('G3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('A2'), np.str_('C3'), np.str_('B-2'), np.str_('B-3'), np.str_('E-4'), np.str_('D4'), np.str_('C4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G#3'), np.str_('G3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5412 - loss: 1.4622 - note_outputs_loss: 0.9210
# Epoch 180/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5384 - loss: 1.4072 - note_outputs_loss: 0.8688
# Epoch 179
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('G#3'), np.str_('C#3'), np.str_('E3'), np.str_('D3'), np.str_('B-2'), np.str_('C3'), np.str_('A2'), np.str_('F#4'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('C#4'), np.str_('D4'), np.str_('E4'), np.str_('D4'), np.str_('C#4'), np.str_('B3'), np.str_('C#4'), np.str_('A3'), np.str_('B3'), np.str_('C#4'), np.str_('D4'), np.str_('C#4'), np.str_('D4'), np.str_('E4'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('B4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5406 - loss: 1.4414 - note_outputs_loss: 0.9009
# Epoch 181/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5011 - loss: 1.3819 - note_outputs_loss: 0.8808
# Epoch 180
# Notes:     ['START', np.str_('E-:major'), np.str_('12/8TS'), np.str_('rest'), np.str_('E-3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('G3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B-3'), np.str_('A3'), np.str_('C4'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('D4'), np.str_('F3'), np.str_('G3'), np.str_('A3'), np.str_('B-3'), np.str_('C4'), np.str_('B-3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5368 - loss: 1.4307 - note_outputs_loss: 0.8939
# Epoch 182/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5930 - loss: 1.4744 - note_outputs_loss: 0.8815
# Epoch 181
# Notes:     ['START', np.str_('C:major'), np.str_('3/4TS'), np.str_('C4'), np.str_('C4'), np.str_('A3'), np.str_('B3'), np.str_('B-3'), np.str_('G3'), np.str_('A3'), np.str_('D3'), np.str_('E3'), np.str_('F3'), np.str_('F3'), np.str_('D3'), np.str_('E3'), np.str_('C3'), np.str_('G2'), np.str_('E2'), np.str_('G2'), np.str_('C4'), np.str_('rest'), np.str_('START'), np.str_('F:major'), np.str_('3/4TS'), np.str_('A3'), np.str_('B-3'), np.str_('B-3'), np.str_('A3'), np.str_('B-3'), np.str_('G3'), np.str_('A3'), np.str_('D3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('2.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5396 - loss: 1.4354 - note_outputs_loss: 0.8958
# Epoch 183/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5332 - loss: 1.3999 - note_outputs_loss: 0.8667
# Epoch 182
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('C3'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('G#2'), np.str_('G2'), np.str_('F2'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('B-2'), np.str_('G2'), np.str_('C#4'), np.str_('B-3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5374 - loss: 1.4340 - note_outputs_loss: 0.8966
# Epoch 184/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.4970 - loss: 1.3854 - note_outputs_loss: 0.8884
# Epoch 183
# Notes:     ['START', np.str_('G:major'), np.str_('4/4TS'), np.str_('A3'), np.str_('B3'), np.str_('C4'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('D3'), np.str_('B3'), np.str_('D3'), np.str_('B3'), np.str_('D3'), np.str_('G2'), np.str_('E3'), np.str_('G3'), np.str_('A3'), np.str_('C3'), np.str_('B2'), np.str_('A3'), np.str_('G3'), np.str_('F#3'), np.str_('E3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('A2'), np.str_('G2'), np.str_('F#2'), np.str_('C3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('3.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('1.0'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5425 - loss: 1.4515 - note_outputs_loss: 0.9091
# Epoch 185/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5380 - loss: 1.3791 - note_outputs_loss: 0.8411
# Epoch 184
# Notes:     ['START', np.str_('D:major'), np.str_('12/8TS'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('F#3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('D3')]
# Durations: ['0.0', np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5448 - loss: 1.4442 - note_outputs_loss: 0.8993
# Epoch 186/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5558 - loss: 1.4252 - note_outputs_loss: 0.8693
# Epoch 185
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('G3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('B-2'), np.str_('G2'), np.str_('G#2'), np.str_('B-2'), np.str_('G2'), np.str_('G#2'), np.str_('B-2'), np.str_('G2'), np.str_('G#2')]
# Durations: ['0.0', np.str_('0.5'), np.str_('1.0'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6'), np.str_('1/12'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6'), np.str_('1/12'), np.str_('0.5'), np.str_('1/12'), np.str_('1/3'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6'), np.str_('1/12'), np.str_('1/3'), np.str_('1/12'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5408 - loss: 1.4327 - note_outputs_loss: 0.8919
# Epoch 187/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5857 - loss: 1.4270 - note_outputs_loss: 0.8413
# Epoch 186
# Notes:     ['START', np.str_('E-:major'), np.str_('12/8TS'), np.str_('rest'), np.str_('E-3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('G3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('A3'), np.str_('F3'), np.str_('E-3'), np.str_('F3'), np.str_('A3'), np.str_('B-3'), np.str_('A3'), np.str_('G3'), np.str_('A3'), np.str_('C4')]
# Durations: ['0.0', np.str_('1.0'), np.str_('1/12'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5392 - loss: 1.4314 - note_outputs_loss: 0.8922
# Epoch 188/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5118 - loss: 1.3692 - note_outputs_loss: 0.8574
# Epoch 187
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('G3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('B2'), np.str_('C3'), np.str_('G#3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('A2'), np.str_('B2'), np.str_('D3'), np.str_('G3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('G3'), np.str_('E-3'), np.str_('C4'), np.str_('G3'), np.str_('A3'), np.str_('F3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('2.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5396 - loss: 1.4366 - note_outputs_loss: 0.8969
# Epoch 189/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5547 - loss: 1.3926 - note_outputs_loss: 0.8378
# Epoch 188
# Notes:     ['START', np.str_('G:major'), np.str_('3/4TS'), np.str_('G2'), np.str_('D3'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('C4'), np.str_('B3'), np.str_('A3'), np.str_('G3'), np.str_('D4'), np.str_('F3'), np.str_('E3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('C3'), np.str_('B3'), np.str_('E3'), np.str_('F3'), np.str_('B2'), np.str_('D3'), np.str_('B2'), np.str_('C3'), np.str_('C4'), np.str_('B3'), np.str_('A3'), np.str_('G#3'), np.str_('A3'), np.str_('D4'), np.str_('E3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5422 - loss: 1.4248 - note_outputs_loss: 0.8826
# Epoch 190/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.4913 - loss: 1.3708 - note_outputs_loss: 0.8795
# Epoch 189
# Notes:     ['START', np.str_('C:major'), np.str_('3/4TS'), np.str_('C4'), np.str_('C4'), np.str_('A3'), np.str_('B3'), np.str_('B-3'), np.str_('B-3'), np.str_('G3'), np.str_('A3'), np.str_('D3'), np.str_('E3'), np.str_('F3'), np.str_('F3'), np.str_('D3'), np.str_('E3'), np.str_('C3'), np.str_('G2'), np.str_('E3'), np.str_('D3'), np.str_('E3'), np.str_('F3'), np.str_('C3'), np.str_('B2'), np.str_('E3'), np.str_('F3'), np.str_('A2'), np.str_('G2'), np.str_('E3'), np.str_('F3'), np.str_('F2'), np.str_('E2')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5401 - loss: 1.4427 - note_outputs_loss: 0.9025
# Epoch 191/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5980 - loss: 1.4552 - note_outputs_loss: 0.8572
# Epoch 190
# Notes:     ['START', np.str_('G:major'), np.str_('6/8TS'), np.str_('rest'), np.str_('F#4'), np.str_('F#4'), np.str_('D4'), np.str_('C4'), np.str_('B3'), np.str_('A3'), np.str_('G3'), np.str_('F#3'), np.str_('E3'), np.str_('C4'), np.str_('B3'), np.str_('C4'), np.str_('A3'), np.str_('B3'), np.str_('G3'), np.str_('F#3'), np.str_('E3'), np.str_('D3'), np.str_('E3'), np.str_('F#3'), np.str_('G2'), np.str_('G3'), np.str_('C4'), np.str_('G3'), np.str_('A3'), np.str_('A3'), np.str_('G3'), np.str_('F#3'), np.str_('E3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5396 - loss: 1.4316 - note_outputs_loss: 0.8921
# Epoch 192/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.4949 - loss: 1.3921 - note_outputs_loss: 0.8972
# Epoch 191
# Notes:     ['START', np.str_('C:major'), np.str_('3/4TS'), np.str_('C4'), np.str_('C4'), np.str_('A3'), np.str_('B3'), np.str_('B-3'), np.str_('G3'), np.str_('A3'), np.str_('D3'), np.str_('E3'), np.str_('F3'), np.str_('F3'), np.str_('D3'), np.str_('E3'), np.str_('F3'), np.str_('G3'), np.str_('A3'), np.str_('B-3'), np.str_('C4'), np.str_('C4'), np.str_('G3'), np.str_('E4'), np.str_('C4'), np.str_('A3'), np.str_('F3'), np.str_('E4'), np.str_('D4'), np.str_('C4'), np.str_('D4'), np.str_('A3'), np.str_('C4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('2.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.75'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('1.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - duration_outputs_loss: 0.5400 - loss: 1.4340 - note_outputs_loss: 0.8940
# Epoch 193/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5143 - loss: 1.3471 - note_outputs_loss: 0.8328
# Epoch 192
# Notes:     ['START', np.str_('E-:major'), np.str_('12/8TS'), np.str_('rest'), np.str_('E-3'), np.str_('E-3'), np.str_('E-3'), np.str_('D3'), np.str_('F3'), np.str_('D3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('C3'), np.str_('B-2'), np.str_('G3'), np.str_('A2'), np.str_('G2'), np.str_('F#2'), np.str_('A2'), np.str_('D3'), np.str_('C4'), np.str_('B-3'), np.str_('F#3'), np.str_('G3'), np.str_('B-3'), np.str_('D4'), np.str_('A3')]
# Durations: ['0.0', np.str_('0.75'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('0.5'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5402 - loss: 1.4146 - note_outputs_loss: 0.8744
# Epoch 194/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5012 - loss: 1.3699 - note_outputs_loss: 0.8687
# Epoch 193
# Notes:     ['START', np.str_('D:major'), np.str_('3/4TS'), np.str_('rest'), np.str_('A3'), np.str_('B3'), np.str_('C4'), np.str_('E3'), np.str_('B3'), np.str_('D3'), np.str_('G3'), np.str_('F#3'), np.str_('E3'), np.str_('D4'), np.str_('D3'), np.str_('A3'), np.str_('E3'), np.str_('A3'), np.str_('F#3'), np.str_('A3'), np.str_('F#3'), np.str_('A3'), np.str_('D3'), np.str_('A3'), np.str_('E3'), np.str_('A3'), np.str_('F#3'), np.str_('A3'), np.str_('D3'), np.str_('A3'), np.str_('G3'), np.str_('A3'), np.str_('E3')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5387 - loss: 1.4289 - note_outputs_loss: 0.8902
# Epoch 195/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5423 - loss: 1.3937 - note_outputs_loss: 0.8514
# Epoch 194
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('B-2'), np.str_('A2'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('G#2'), np.str_('G2'), np.str_('F2'), np.str_('E-2'), np.str_('G2'), np.str_('B2'), np.str_('D3'), np.str_('F3'), np.str_('G#3'), np.str_('G3'), np.str_('D3'), np.str_('E-3'), np.str_('G2'), np.str_('C3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('2.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - duration_outputs_loss: 0.5358 - loss: 1.4192 - note_outputs_loss: 0.8835
# Epoch 196/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5481 - loss: 1.4043 - note_outputs_loss: 0.8563
# Epoch 195
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('C#4'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('B-2'), np.str_('G2')]
# Durations: ['0.0', np.str_('3.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - duration_outputs_loss: 0.5406 - loss: 1.4200 - note_outputs_loss: 0.8793
# Epoch 197/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5445 - loss: 1.3775 - note_outputs_loss: 0.8330
# Epoch 196
# Notes:     ['START', np.str_('E-:major'), np.str_('3/4TS'), np.str_('G3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('G#2'), np.str_('B-2'), np.str_('G3'), np.str_('B-3'), np.str_('D3'), np.str_('E-3'), np.str_('G2'), np.str_('B-2'), np.str_('E-2'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('C3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('D3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5444 - loss: 1.4291 - note_outputs_loss: 0.8847
# Epoch 198/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - duration_outputs_loss: 0.5001 - loss: 1.3486 - note_outputs_loss: 0.8485
# Epoch 197
# Notes:     ['START', np.str_('G:major'), np.str_('4/4TS'), np.str_('G2'), np.str_('D3'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('D3'), np.str_('B3'), np.str_('D3'), np.str_('G2'), np.str_('D3'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('D3'), np.str_('G2'), np.str_('D3'), np.str_('B3'), np.str_('G3'), np.str_('A3'), np.str_('F#3'), np.str_('D4'), np.str_('B3'), np.str_('C4'), np.str_('E3'), np.str_('C4'), np.str_('E3'), np.str_('G4'), np.str_('D4'), np.str_('E4'), np.str_('F#4')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5411 - loss: 1.4167 - note_outputs_loss: 0.8756
# Epoch 199/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - duration_outputs_loss: 0.5949 - loss: 1.4583 - note_outputs_loss: 0.8634
# Epoch 198
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('C3'), np.str_('C3'), np.str_('B-2'), np.str_('D3'), np.str_('G#2'), np.str_('G2'), np.str_('B-2'), np.str_('E-3'), np.str_('G3'), np.str_('B-3'), np.str_('D3'), np.str_('C3'), np.str_('B-2'), np.str_('C3'), np.str_('G#2'), np.str_('C3'), np.str_('G2'), np.str_('F2'), np.str_('G#2'), np.str_('D3'), np.str_('F3'), np.str_('B-3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('B-2'), np.str_('G2'), np.str_('B-2'), np.str_('C3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('5.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - duration_outputs_loss: 0.5386 - loss: 1.4211 - note_outputs_loss: 0.8824
# Epoch 200/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.4918 - loss: 1.3360 - note_outputs_loss: 0.8443
# Epoch 199
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('C4'), np.str_('C4'), np.str_('C4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('G3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-2'), np.str_('E-2'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('D3'), np.str_('E-3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5397 - loss: 1.4166 - note_outputs_loss: 0.8769
# Epoch 201/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5297 - loss: 1.3941 - note_outputs_loss: 0.8644
# Epoch 200
# Notes:     ['START', np.str_('D:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('F#4'), np.str_('G4'), np.str_('F#4'), np.str_('E4'), np.str_('E4'), np.str_('D4'), np.str_('D4'), np.str_('C#4'), np.str_('E4'), np.str_('E4'), np.str_('E4'), np.str_('F#4'), np.str_('G4'), np.str_('E4'), np.str_('A3'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('E4'), np.str_('D4'), np.str_('D4'), np.str_('C#4'), np.str_('E4'), np.str_('B3'), np.str_('E4'), np.str_('C#4'), np.str_('E4'), np.str_('C#4'), np.str_('E4')]
# Durations: ['0.0', np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5393 - loss: 1.4172 - note_outputs_loss: 0.8779
# Epoch 202/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5433 - loss: 1.4005 - note_outputs_loss: 0.8572
# Epoch 201
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('G3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('B2'), np.str_('C3'), np.str_('G#3'), np.str_('E-3'), np.str_('F3'), np.str_('D3'), np.str_('B2'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('G#2'), np.str_('G2'), np.str_('B2'), np.str_('D3'), np.str_('B2'), np.str_('A2')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('3.75'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - duration_outputs_loss: 0.5399 - loss: 1.4298 - note_outputs_loss: 0.8899
# Epoch 203/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - duration_outputs_loss: 0.5560 - loss: 1.4139 - note_outputs_loss: 0.8579
# Epoch 202
# ...
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5279 - loss: 1.1773 - note_outputs_loss: 0.6494
# Epoch 989/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5416 - loss: 1.1808 - note_outputs_loss: 0.6392
# Epoch 988
# Notes:     ['START', np.str_('D:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('F#4'), np.str_('F#4'), np.str_('G4'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('D4'), np.str_('C#4'), np.str_('E4'), np.str_('E4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('D4'), np.str_('A4'), np.str_('A4'), np.str_('G4'), np.str_('E4'), np.str_('E4'), np.str_('F#4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('B4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('0.0'), np.str_('3.75'), np.str_('0.25'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - duration_outputs_loss: 0.5275 - loss: 1.1727 - note_outputs_loss: 0.6453
# Epoch 990/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5656 - loss: 1.1927 - note_outputs_loss: 0.6270
# Epoch 989
# Notes:     ['START', np.str_('D:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('F#4'), np.str_('F#4'), np.str_('G4'), np.str_('F#4'), np.str_('E4'), np.str_('E4'), np.str_('D4'), np.str_('D4'), np.str_('C#4'), np.str_('E4'), np.str_('E4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('C#4'), np.str_('D4'), np.str_('A4'), np.str_('A4'), np.str_('G4'), np.str_('E4'), np.str_('E4'), np.str_('F#4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4'), np.str_('G4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5296 - loss: 1.1703 - note_outputs_loss: 0.6406
# Epoch 991/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.4981 - loss: 1.0979 - note_outputs_loss: 0.5998
# Epoch 990
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G3'), np.str_('G#3'), np.str_('G#3'), np.str_('F3'), np.str_('F2'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('E-3'), np.str_('E-2'), np.str_('E-3'), np.str_('F3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/12'), np.str_('1/6'), np.str_('1/12'), np.str_('1/6'), np.str_('1/12'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - duration_outputs_loss: 0.5306 - loss: 1.1623 - note_outputs_loss: 0.6317
# Epoch 992/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.4738 - loss: 1.0809 - note_outputs_loss: 0.6072
# Epoch 991
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('C3'), np.str_('C3'), np.str_('G2'), np.str_('A2'), np.str_('B2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('E-3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('G#3'), np.str_('G#3'), np.str_('F3'), np.str_('B-3'), np.str_('E3'), np.str_('G#3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('D4'), np.str_('C4'), np.str_('B-3'), np.str_('C4'), np.str_('C4'), np.str_('B-3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5302 - loss: 1.1657 - note_outputs_loss: 0.6354
# Epoch 993/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5034 - loss: 1.1151 - note_outputs_loss: 0.6118
# Epoch 992
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('C4'), np.str_('C4'), np.str_('C4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('G3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('G#2'), np.str_('C3'), np.str_('G2'), np.str_('F2'), np.str_('E-3'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('B2'), np.str_('D3'), np.str_('G2'), np.str_('G3'), np.str_('F3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1/3'), np.str_('4/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3'), np.str_('1/3')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - duration_outputs_loss: 0.5312 - loss: 1.1646 - note_outputs_loss: 0.6335
# Epoch 994/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.5009 - loss: 1.1383 - note_outputs_loss: 0.6374
# Epoch 993
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('E-4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C#4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3'), np.str_('G3'), np.str_('B-2'), np.str_('E-2'), np.str_('C#4'), np.str_('B-3'), np.str_('G3'), np.str_('B-3'), np.str_('E-3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.75'), np.str_('0.25'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - duration_outputs_loss: 0.5273 - loss: 1.1775 - note_outputs_loss: 0.6502
# Epoch 995/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.4957 - loss: 1.1132 - note_outputs_loss: 0.6174
# Epoch 994
# Notes:     ['START', np.str_('E-:major'), np.str_('3/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('G#2'), np.str_('F2'), np.str_('D3'), np.str_('E-3'), np.str_('E-2'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('F3'), np.str_('G3'), np.str_('A3'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('F3'), np.str_('A3'), np.str_('E-3'), np.str_('B-2'), np.str_('C3'), np.str_('D3'), np.str_('E-3'), np.str_('C4'), np.str_('A3'), np.str_('B-3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('2.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('1.0'), np.str_('1.0'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5284 - loss: 1.1754 - note_outputs_loss: 0.6470
# Epoch 996/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.4985 - loss: 1.1244 - note_outputs_loss: 0.6260
# Epoch 995
# Notes:     ['START', np.str_('F:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('F#4'), np.str_('F#4'), np.str_('F#4'), np.str_('E4'), np.str_('D4'), np.str_('C#4'), np.str_('B3'), np.str_('C#4'), np.str_('D3'), np.str_('F#3'), np.str_('G#3'), np.str_('A3'), np.str_('B3'), np.str_('C#4'), np.str_('D4'), np.str_('F#4'), np.str_('F#4'), np.str_('G#4'), np.str_('A4'), np.str_('F#4'), np.str_('D4'), np.str_('C#4'), np.str_('D4'), np.str_('B3'), np.str_('C#4'), np.str_('D4'), np.str_('B3'), np.str_('C#4'), np.str_('D4')]
# Durations: ['0.0', np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - duration_outputs_loss: 0.5304 - loss: 1.1750 - note_outputs_loss: 0.6446
# Epoch 997/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5785 - loss: 1.1996 - note_outputs_loss: 0.6211
# Epoch 996
# Notes:     ['START', np.str_('E-:major'), np.str_('3/4TS'), np.str_('B-3'), np.str_('F3'), np.str_('G3'), np.str_('B-2'), np.str_('E-3'), np.str_('D3'), np.str_('B-3'), np.str_('E3'), np.str_('G3'), np.str_('B-2'), np.str_('G2'), np.str_('C#4'), np.str_('B-3'), np.str_('B3'), np.str_('F3'), np.str_('E3'), np.str_('G3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('E3'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('F3'), np.str_('E3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('0.0'), np.str_('3.75'), np.str_('0.25'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5290 - loss: 1.1685 - note_outputs_loss: 0.6395
# Epoch 998/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5341 - loss: 1.1493 - note_outputs_loss: 0.6152
# Epoch 997
# Notes:     ['START', np.str_('G:major'), np.str_('3/4TS'), np.str_('G2'), np.str_('D3'), np.str_('B3'), np.str_('A3'), np.str_('B3'), np.str_('C4'), np.str_('B3'), np.str_('A3'), np.str_('G3'), np.str_('D4'), np.str_('F3'), np.str_('E3'), np.str_('D3'), np.str_('C3'), np.str_('B2'), np.str_('A2'), np.str_('G2'), np.str_('B3'), np.str_('C4'), np.str_('B3'), np.str_('E3'), np.str_('B3'), np.str_('A2'), np.str_('C4'), np.str_('D4'), np.str_('C4'), np.str_('F#3'), np.str_('C4'), np.str_('B2'), np.str_('D4')]
# Durations: ['0.0', np.str_('0.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5281 - loss: 1.1703 - note_outputs_loss: 0.6423
# Epoch 999/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - duration_outputs_loss: 0.5155 - loss: 1.1282 - note_outputs_loss: 0.6128
# Epoch 998
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('C4'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('F2'), np.str_('D3'), np.str_('E-3'), np.str_('F3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('G3'), np.str_('G#3'), np.str_('B-3'), np.str_('F3'), np.str_('E-3'), np.str_('E-3'), np.str_('C3'), np.str_('G#3')]
# Durations: ['0.0', np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - duration_outputs_loss: 0.5308 - loss: 1.1736 - note_outputs_loss: 0.6428
# Epoch 1000/1000
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - duration_outputs_loss: 0.4769 - loss: 1.1021 - note_outputs_loss: 0.6252
# Epoch 999
# Notes:     ['START', np.str_('E-:major'), np.str_('4/4TS'), np.str_('rest'), np.str_('C4'), np.str_('C4'), np.str_('C4'), np.str_('B-3'), np.str_('G#3'), np.str_('G3'), np.str_('G#3'), np.str_('F3'), np.str_('G3'), np.str_('D3'), np.str_('E-3'), np.str_('C3'), np.str_('B-2'), np.str_('G#2'), np.str_('G2'), np.str_('G#2'), np.str_('F2'), np.str_('G2'), np.str_('D3'), np.str_('D3'), np.str_('D3'), np.str_('C3'), np.str_('C3'), np.str_('G3'), np.str_('G#2'), np.str_('G3'), np.str_('F3'), np.str_('E-3'), np.str_('D3')]
# Durations: ['0.0', np.str_('0.0'), np.str_('2.0'), np.str_('1.0'), np.str_('1.0'), np.str_('1.0'), np.str_('0.5'), np.str_('0.5'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.25'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5'), np.str_('0.5')]
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - duration_outputs_loss: 0.5292 - loss: 1.1737 - note_outputs_loss: 0.6445

# %%
# Save the final model
model.save("./models/model")

# %% [markdown]
# # 3. Generate music using the Transformer

# %%
notes, durations = music_generator.generate(
    ["START"], ["0.0"], max_tokens=50
)
midi_stream = music21.stream.Stream()
midi_stream.append(music21.clef.BassClef())
for n, d in zip(notes, durations):
    new_note = get_midi_note(n, d)
    if new_note is not None:
        midi_stream.append(new_note)

midi_stream = midi_stream.chordify()
midi_stream.show('text')
midi_stream.show('midi')

"""## Write music to MIDI file"""

timestr = time.strftime("%Y%m%d-%H%M%S")

output_dir = "./outputs"
os.makedirs(output_dir, exist_ok=True)

midi_stream.write(
    "midi",
    fp=os.path.join(output_dir, f"output-{timestr}.mid"),
)
# Out:
# {0.0} <music21.clef.BassClef>
# {0.0} <music21.key.Key of E- major>
# {0.0} <music21.meter.TimeSignature 4/4>
# {0.0} <music21.note.Rest 5.5ql>
# {5.5} <music21.chord.Chord E-3>
# {6.0} <music21.chord.Chord F3>
# {6.5} <music21.chord.Chord G3>
# {7.0} <music21.chord.Chord G#3>
# {7.5} <music21.chord.Chord B-3>
# {8.0} <music21.chord.Chord C4>
# {8.5} <music21.chord.Chord G#3>
# {9.0} <music21.chord.Chord B-3>
# {9.5} <music21.chord.Chord C4>
# {10.0} <music21.chord.Chord G3>
# {10.5} <music21.chord.Chord G#3>
# {11.0} <music21.chord.Chord F3>
# {11.5} <music21.chord.Chord F2>
# {12.0} <music21.chord.Chord D3>
# {12.5} <music21.chord.Chord E-3>
# {13.0} <music21.chord.Chord F3>
# {13.5} <music21.chord.Chord G3>
# {14.0} <music21.chord.Chord G#3>
# {14.5} <music21.chord.Chord B-3>
# {15.0} <music21.chord.Chord G3>
# {15.5} <music21.chord.Chord G#3>
# {16.0} <music21.chord.Chord B-3>
# {16.5} <music21.chord.Chord F3>
# {17.0} <music21.chord.Chord G3>
# {17.5} <music21.chord.Chord E-3>
# {18.0} <music21.chord.Chord E-2>
# {18.5} <music21.chord.Chord E-3>
# {19.0} <music21.chord.Chord F3>
# {19.5} <music21.chord.Chord G3>
# {20.0} <music21.chord.Chord G#3>
# {20.5} <music21.chord.Chord B-3>
# {21.0} <music21.chord.Chord B-2>
# {21.5} <music21.chord.Chord C3>
# {22.0} <music21.chord.Chord D3>
# {22.5} <music21.chord.Chord E-3>
# {23.0} <music21.chord.Chord F3>
# {23.5} <music21.chord.Chord G#3>
# {24.0} <music21.chord.Chord G#3>
# {24.5} <music21.chord.Chord G3>
# {25.0} <music21.chord.Chord F3>
# {25.5} <music21.chord.Chord E-3>
# {26.0} <music21.chord.Chord F3>
# {26.5} <music21.chord.Chord E-3>
# {27.0} <music21.chord.Chord F3>
# {27.5} <music21.chord.Chord G3>
# {28.0} <music21.chord.Chord G#3>
# {28.5} <music21.chord.Chord B-3>
#         <div id="midiPlayerDiv977877"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv977877_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv977877");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv977877_play, 2000);
#         } else {
#             midiPlayerDiv977877_play();
#         }
#         </script>
# './outputs/output-20260412-072850.mid'

# %% [markdown]
# ## Write music to MIDI file

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")
output_dir = "./outputs"
os.makedirs(output_dir, exist_ok=True)

midi_stream.write(
    "midi",
    fp=os.path.join(output_dir, f"output-{timestr}.mid"),
)
# Out:
# './outputs/output-20260412-072113.mid'

# %% [markdown]
# ## Note probabilities

# %%
max_pitch = 70
seq_len = len(info)
grid = np.zeros((max_pitch, seq_len), dtype=np.float32)

for j in range(seq_len):
    for i, prob in enumerate(info[j]["note_probs"]):
        try:
            pitch = music21.note.Note(notes_vocab[i]).pitch.midi
            grid[pitch, j] = prob
        except:
            pass  # Don't show key / time signatures

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_yticks([int(j) for j in range(35, 70)])
plt.imshow(
    grid[35:70, :],
    origin="lower",
    cmap="coolwarm",
    vmin=-0.5,
    vmax=0.5,
    extent=[0, seq_len, 35, 70],
)
plt.show()

# %% [markdown]
# ## Attention Plot

# %%
plot_size = 20

att_matrix = np.zeros((plot_size, plot_size))
prediction_output = []
last_prompt = []

# %%
for j in range(plot_size):
    atts = info[j]["atts"].max(axis=0)
    att_matrix[: (j + 1), j] = atts
    prediction_output.append(info[j]["chosen_note"][0])
    last_prompt.append(info[j]["prompt"][0][-1])

# %%
fig, ax = plt.subplots(figsize=(8, 8))
im = ax.imshow(att_matrix, cmap="Greens", interpolation="nearest")

ax.set_xticks(np.arange(-0.5, plot_size, 1), minor=True)
ax.set_yticks(np.arange(-0.5, plot_size, 1), minor=True)
ax.grid(which="minor", color="black", linestyle="-", linewidth=1)
ax.set_xticks(np.arange(plot_size))
ax.set_yticks(np.arange(plot_size))
ax.set_xticklabels(prediction_output[:plot_size])
ax.set_yticklabels(last_prompt[:plot_size])
ax.xaxis.tick_top()

plt.setp(
    ax.get_xticklabels(),
    rotation=90,
    ha="left",
    va="center",
    rotation_mode="anchor",
)
plt.show()
